# %%
# Imports
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import accuracy_score, mean_squared_error

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GRU, SimpleRNN, LSTM
from tensorflow.keras.optimizers import Adam, Adagrad
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

from statsmodels.graphics.tsaplots import plot_acf
import random
import os

# %%
# setting `PYTHONHASHSEED` environment variable at a fixed value
os.environ['PYTHONHASHSEED']=str(42)

# %%
# setting a random seed for reproducibility
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# %%
# reading int the data into a pandas dataframe
df = pd.read_csv('../datasets/us_state_vaccinations.csv')

# %%
# first look at the data
df.head()
# Out:
#          date location  total_vaccinations  total_distributed  \
# 0  2021-01-12  Alabama             78134.0           377025.0
# 1  2021-01-13  Alabama             84040.0           378975.0
# 2  2021-01-14  Alabama             92300.0           435350.0
# 3  2021-01-15  Alabama            100567.0           444650.0
# 4  2021-01-16  Alabama                 NaN                NaN
#
#    people_vaccinated  people_fully_vaccinated_per_hundred  \
# 0            70861.0                                 0.15
# 1            74792.0                                 0.19
# 2            80480.0                                  NaN
# 3            86956.0                                 0.28
# 4                NaN                                  NaN
#
#    total_vaccinations_per_hundred  people_fully_vaccinated  \
# 0                            1.59                   7270.0
# 1                            1.71                   9245.0
# 2                            1.88                      NaN
# 3                            2.05                  13488.0
# 4                             NaN                      NaN
#
#    people_vaccinated_per_hundred  distributed_per_hundred  \
# 0                           1.45                     7.69
# 1                           1.53                     7.73
# 2                           1.64                     8.88
# 3                           1.77                     9.07
# 4                            NaN                      NaN
#
#    daily_vaccinations_raw  daily_vaccinations  daily_vaccinations_per_million  \
# 0                     NaN                 NaN                             NaN
# 1                  5906.0              5906.0                          1205.0
# 2                  8260.0              7083.0                          1445.0
# 3                  8267.0              7478.0                          1525.0
# 4                  7557.0              7498.0                          1529.0
#
#    share_doses_used
# 0             0.207
# 1             0.222
# 2             0.212
# 3             0.226
# 4               NaN

# %%
# setting the index to be the date column
df.set_index('date', inplace=True)

# %%
# sorting the index
df.sort_index(axis=1, inplace=True)

# %%
df.shape
# Out:
# (6198, 13)

# %%
# setting the index to datetime
df.index = pd.to_datetime(df.index)

# %%
# confirming that the index is in datetime format
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6198 entries, 2021-01-12 to 2021-04-16
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   daily_vaccinations                   6133 non-null   float64
#  1   daily_vaccinations_per_million       5722 non-null   float64
#  2   daily_vaccinations_raw               6133 non-null   float64
#  3   distributed_per_hundred              5519 non-null   float64
#  4   location                             6198 non-null   object
#  5   people_fully_vaccinated              5733 non-null   float64
#  6   people_fully_vaccinated_per_hundred  5430 non-null   float64
#  7   people_vaccinated                    5815 non-null   float64
#  8   people_vaccinated_per_hundred        5507 non-null   float64
#  9   share_doses_used                     5827 non-null   float64
#  10  total_distributed                    5827 non-null   float64
#  11  total_vaccinations                   5928 non-null   float64
#  12  total_vaccinations_per_hundred       5532 non-null   float64
# dtypes: float64(12), object(1)
# memory usage: 677.9+ KB

# %%
# creating a mask to set the dataframe only equal to the state of massachusetts
mask = df['location'] == 'Massachusetts'
df = df[mask]

# %%
# checking for null values
df.isnull().sum()
# Out:
# daily_vaccinations                     1
# daily_vaccinations_per_million         1
# daily_vaccinations_raw                 1
# distributed_per_hundred                4
# location                               0
# people_fully_vaccinated                5
# people_fully_vaccinated_per_hundred    5
# people_vaccinated                      4
# people_vaccinated_per_hundred          4
# share_doses_used                       4
# total_distributed                      4
# total_vaccinations                     4
# total_vaccinations_per_hundred         4
# dtype: int64

# %%
df.head(20)
# Out:
#             daily_vaccinations  daily_vaccinations_per_million  \
# date
# 2021-01-12                 NaN                             NaN
# 2021-01-13             13361.0                          1938.0
# 2021-01-14             14697.0                          2132.0
# 2021-01-15             17698.0                          2568.0
# 2021-01-16             17130.0                          2485.0
# 2021-01-17             16789.0                          2436.0
# 2021-01-18             16562.0                          2403.0
# 2021-01-19             16399.0                          2379.0
# 2021-01-20             16150.0                          2343.0
# 2021-01-21             17092.0                          2480.0
# 2021-01-22             16207.0                          2351.0
# 2021-01-23             17195.0                          2495.0
# 2021-01-24             18826.0                          2731.0
# 2021-01-25             18595.0                          2698.0
# 2021-01-26             17689.0                          2566.0
# 2021-01-27             19112.0                          2773.0
# 2021-01-28             19602.0                          2844.0
# 2021-01-29             21411.0                          3106.0
# 2021-01-30             22016.0                          3194.0
# 2021-01-31             22768.0                          3303.0
#
#             daily_vaccinations_raw  distributed_per_hundred       location  \
# date
# 2021-01-12                     NaN                     6.91  Massachusetts
# 2021-01-13                 13361.0                     9.53  Massachusetts
# 2021-01-14                 16033.0                     9.71  Massachusetts
# 2021-01-15                 23699.0                     9.71  Massachusetts
# 2021-01-16                 15425.5                      NaN  Massachusetts
# 2021-01-17                 15425.5                      NaN  Massachusetts
# 2021-01-18                 15425.5                      NaN  Massachusetts
# 2021-01-19                 15425.5                     9.71  Massachusetts
# 2021-01-20                 11613.0                    10.70  Massachusetts
# 2021-01-21                 22627.0                    11.26  Massachusetts
# 2021-01-22                 17510.0                    12.40  Massachusetts
# 2021-01-23                 22340.0                    12.47  Massachusetts
# 2021-01-24                 26839.0                    12.47  Massachusetts
# 2021-01-25                 13809.0                    12.47  Massachusetts
# 2021-01-26                  9088.0                    12.71  Massachusetts
# 2021-01-27                 21572.0                    13.88  Massachusetts
# 2021-01-28                 26057.0                    14.78  Massachusetts
# 2021-01-29                 30172.0                    15.34  Massachusetts
# 2021-01-30                 26578.0                    15.39  Massachusetts
# 2021-01-31                 32099.0                    15.39  Massachusetts
#
#             people_fully_vaccinated  people_fully_vaccinated_per_hundred  \
# date
# 2021-01-12                  19073.0                                 0.28
# 2021-01-13                  24789.0                                 0.36
# 2021-01-14                      NaN                                  NaN
# 2021-01-15                  34885.0                                 0.51
# 2021-01-16                      NaN                                  NaN
# 2021-01-17                      NaN                                  NaN
# 2021-01-18                      NaN                                  NaN
# 2021-01-19                  41053.0                                 0.60
# 2021-01-20                  42062.0                                 0.61
# 2021-01-21                  46247.0                                 0.67
# 2021-01-22                  51662.0                                 0.75
# 2021-01-23                  57869.0                                 0.84
# 2021-01-24                  63096.0                                 0.92
# 2021-01-25                  64648.0                                 0.94
# 2021-01-26                  65761.0                                 0.95
# 2021-01-27                  73152.0                                 1.06
# 2021-01-28                  83637.0                                 1.21
# 2021-01-29                  96373.0                                 1.40
# 2021-01-30                 106799.0                                 1.55
# 2021-01-31                 116315.0                                 1.69
#
#             people_vaccinated  people_vaccinated_per_hundred  \
# date
# 2021-01-12           184984.0                           2.68
# 2021-01-13           192619.0                           2.79
# 2021-01-14           204481.0                           2.97
# 2021-01-15           222109.0                           3.22
# 2021-01-16                NaN                            NaN
# 2021-01-17                NaN                            NaN
# 2021-01-18                NaN                            NaN
# 2021-01-19           277612.0                           4.03
# 2021-01-20           288209.0                           4.18
# 2021-01-21           306646.0                           4.45
# 2021-01-22           318630.0                           4.62
# 2021-01-23           334514.0                           4.85
# 2021-01-24           356102.0                           5.17
# 2021-01-25           368358.0                           5.34
# 2021-01-26           376313.0                           5.46
# 2021-01-27           390470.0                           5.67
# 2021-01-28           406024.0                           5.89
# 2021-01-29           422803.0                           6.13
# 2021-01-30           438852.0                           6.37
# 2021-01-31           461408.0                           6.69
#
#             share_doses_used  total_distributed  total_vaccinations  \
# date
# 2021-01-12             0.429           476025.0            204082.0
# 2021-01-13             0.331           656850.0            217443.0
# 2021-01-14             0.349           669225.0            233476.0
# 2021-01-15             0.384           669325.0            257175.0
# 2021-01-16               NaN                NaN                 NaN
# 2021-01-17               NaN                NaN                 NaN
# 2021-01-18               NaN                NaN                 NaN
# 2021-01-19             0.476           669325.0            318877.0
# 2021-01-20             0.448           737550.0            330490.0
# 2021-01-21             0.455           776400.0            353117.0
# 2021-01-22             0.434           854950.0            370627.0
# 2021-01-23             0.457           859175.0            392967.0
# 2021-01-24             0.489           859175.0            419806.0
# 2021-01-25             0.505           859175.0            433615.0
# 2021-01-26             0.505           875825.0            442703.0
# 2021-01-27             0.485           956800.0            464275.0
# 2021-01-28             0.481          1018975.0            490332.0
# 2021-01-29             0.492          1057000.0            520504.0
# 2021-01-30             0.516          1060900.0            547082.0
# 2021-01-31             0.546          1060900.0            579181.0
#
#             total_vaccinations_per_hundred
# date
# 2021-01-12                            2.96
# 2021-01-13                            3.15
# 2021-01-14                            3.39
# 2021-01-15                            3.73
# 2021-01-16                             NaN
# 2021-01-17                             NaN
# 2021-01-18                             NaN
# 2021-01-19                            4.63
# 2021-01-20                            4.79
# 2021-01-21                            5.12
# 2021-01-22                            5.38
# 2021-01-23                            5.70
# 2021-01-24                            6.09
# 2021-01-25                            6.29
# 2021-01-26                            6.42
# 2021-01-27                            6.74
# 2021-01-28                            7.11
# 2021-01-29                            7.55
# 2021-01-30                            7.94
# 2021-01-31                            8.40

# %% [markdown]
# Only missing data through 6 rows

# %%
df.shape
# Out:
# (95, 13)

# %%
# dropping rows with missing values
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (89, 13)

# %%
df.index.unique()
# Out:
# DatetimeIndex(['2021-01-13', '2021-01-15', '2021-01-19', '2021-01-20',
#                '2021-01-21', '2021-01-22', '2021-01-23', '2021-01-24',
#                '2021-01-25', '2021-01-26', '2021-01-27', '2021-01-28',
#                '2021-01-29', '2021-01-30', '2021-01-31', '2021-02-01',
#                '2021-02-02', '2021-02-03', '2021-02-04', '2021-02-05',
#                '2021-02-06', '2021-02-07', '2021-02-08', '2021-02-09',
#                '2021-02-10', '2021-02-11', '2021-02-12', '2021-02-13',
#                '2021-02-14', '2021-02-16', '2021-02-17', '2021-02-18',
#                '2021-02-19', '2021-02-20', '2021-02-21', '2021-02-22',
#                '2021-02-23', '2021-02-24', '2021-02-25', '2021-02-26',
#                '2021-02-27', '2021-02-28', '2021-03-01', '2021-03-02',
#                '2021-03-03', '2021-03-04', '2021-03-05', '2021-03-06',
#                '2021-03-07', '2021-03-08', '2021-03-09', '2021-03-10',
#                '2021-03-11', '2021-03-12', '2021-03-13', '2021-03-14',
#                '2021-03-15', '2021-03-16', '2021-03-17', '2021-03-18',
#                '2021-03-19', '2021-03-20', '2021-03-21', '2021-03-22',
#                '2021-03-23', '2021-03-24', '2021-03-25', '2021-03-26',
#                '2021-03-27', '2021-03-28', '2021-03-29', '2021-03-30',
#                '2021-03-31', '2021-04-01', '2021-04-02', '2021-04-03',
#                '2021-04-04', '2021-04-05', '2021-04-06', '2021-04-07',
#                '2021-04-08', '2021-04-09', '2021-04-10', '2021-04-11',
#                '2021-04-12', '2021-04-13', '2021-04-14', '2021-04-15',
#                '2021-04-16'],
#               dtype='datetime64[ns]', name='date', freq=None)

# %% [markdown]
# jan 12, 14 16 17 18 were dropped
# Feb 15 was dropped
# Should I just drop the first several rows then? I think it'll make the data confusing.
# Also, need to look into feb 15, and probably impute on that row

# %%
# dropping the first two rows in order to keep continuity in time steps
df.drop(df.loc[df.index == '2021-01-13'].index, inplace=True)

# %%
df.drop(df.loc[df.index == '2021-01-15'].index, inplace=True)

# %%
df.head(3)
# Out:
#             daily_vaccinations  daily_vaccinations_per_million  \
# date
# 2021-01-19             16399.0                          2379.0
# 2021-01-20             16150.0                          2343.0
# 2021-01-21             17092.0                          2480.0
#
#             daily_vaccinations_raw  distributed_per_hundred       location  \
# date
# 2021-01-19                 15425.5                     9.71  Massachusetts
# 2021-01-20                 11613.0                    10.70  Massachusetts
# 2021-01-21                 22627.0                    11.26  Massachusetts
#
#             people_fully_vaccinated  people_fully_vaccinated_per_hundred  \
# date
# 2021-01-19                  41053.0                                 0.60
# 2021-01-20                  42062.0                                 0.61
# 2021-01-21                  46247.0                                 0.67
#
#             people_vaccinated  people_vaccinated_per_hundred  \
# date
# 2021-01-19           277612.0                           4.03
# 2021-01-20           288209.0                           4.18
# 2021-01-21           306646.0                           4.45
#
#             share_doses_used  total_distributed  total_vaccinations  \
# date
# 2021-01-19             0.476           669325.0            318877.0
# 2021-01-20             0.448           737550.0            330490.0
# 2021-01-21             0.455           776400.0            353117.0
#
#             total_vaccinations_per_hundred
# date
# 2021-01-19                            4.63
# 2021-01-20                            4.79
# 2021-01-21                            5.12

# %%
#HAVE TO FILL IN DATA FOR 2/15 HERE!

# %%
df.loc[df.index == '2021-02-16']
# Out:
#             daily_vaccinations  daily_vaccinations_per_million  \
# date
# 2021-02-16             44945.0                          6521.0
#
#             daily_vaccinations_raw  distributed_per_hundred       location  \
# date
# 2021-02-16                 30638.0                    22.01  Massachusetts
#
#             people_fully_vaccinated  people_fully_vaccinated_per_hundred  \
# date
# 2021-02-16                 280622.0                                 4.07
#
#             people_vaccinated  people_vaccinated_per_hundred  \
# date
# 2021-02-16           863806.0                          12.53
#
#             share_doses_used  total_distributed  total_vaccinations  \
# date
# 2021-02-16             0.756          1517375.0           1146860.0
#
#             total_vaccinations_per_hundred
# date
# 2021-02-16                           16.64

# %%
# dropping the location column
df.drop('location', axis=1, inplace=True)
df.head()
# Out:
#             daily_vaccinations  daily_vaccinations_per_million  \
# date
# 2021-01-19             16399.0                          2379.0
# 2021-01-20             16150.0                          2343.0
# 2021-01-21             17092.0                          2480.0
# 2021-01-22             16207.0                          2351.0
# 2021-01-23             17195.0                          2495.0
#
#             daily_vaccinations_raw  distributed_per_hundred  \
# date
# 2021-01-19                 15425.5                     9.71
# 2021-01-20                 11613.0                    10.70
# 2021-01-21                 22627.0                    11.26
# 2021-01-22                 17510.0                    12.40
# 2021-01-23                 22340.0                    12.47
#
#             people_fully_vaccinated  people_fully_vaccinated_per_hundred  \
# date
# 2021-01-19                  41053.0                                 0.60
# 2021-01-20                  42062.0                                 0.61
# 2021-01-21                  46247.0                                 0.67
# 2021-01-22                  51662.0                                 0.75
# 2021-01-23                  57869.0                                 0.84
#
#             people_vaccinated  people_vaccinated_per_hundred  \
# date
# 2021-01-19           277612.0                           4.03
# 2021-01-20           288209.0                           4.18
# 2021-01-21           306646.0                           4.45
# 2021-01-22           318630.0                           4.62
# 2021-01-23           334514.0                           4.85
#
#             share_doses_used  total_distributed  total_vaccinations  \
# date
# 2021-01-19             0.476           669325.0            318877.0
# 2021-01-20             0.448           737550.0            330490.0
# 2021-01-21             0.455           776400.0            353117.0
# 2021-01-22             0.434           854950.0            370627.0
# 2021-01-23             0.457           859175.0            392967.0
#
#             total_vaccinations_per_hundred
# date
# 2021-01-19                            4.63
# 2021-01-20                            4.79
# 2021-01-21                            5.12
# 2021-01-22                            5.38
# 2021-01-23                            5.70

# %% [markdown]
# ## Plotting features to evaluate trend

# %%
df.columns
# Out:
# Index(['daily_vaccinations', 'daily_vaccinations_per_million',
#        'daily_vaccinations_raw', 'distributed_per_hundred',
#        'people_fully_vaccinated', 'people_fully_vaccinated_per_hundred',
#        'people_vaccinated', 'people_vaccinated_per_hundred',
#        'share_doses_used', 'total_distributed', 'total_vaccinations',
#        'total_vaccinations_per_hundred'],
#       dtype='object')

# %%
df['total_vaccinations'].plot();

# %%
df['people_fully_vaccinated'].plot();

# %%
df['people_vaccinated'].plot();

# %%
plt.plot(df['daily_vaccinations']);

# %%
plot_acf(df['daily_vaccinations'], lags=20);

# %% [markdown]
# Autocorrelation plot confirms the positive trend

# %%
from statsmodels.tsa.stattools import adfuller

# Code written by Joseph Nelson.

def interpret_dftest(dftest):
    dfoutput = pd.Series(dftest[0:2], index=['Test Statistic','p-value'])
    return dfoutput

# Run ADF test on original (non-differenced!) data.
interpret_dftest(adfuller(df['daily_vaccinations']))
# Out:
# Test Statistic   -0.102637
# p-value           0.949175
# dtype: float64

# %% [markdown]
# daily vaccinations is not stationary

# %%
# Run ADF test on differenced data.
interpret_dftest(adfuller(df['daily_vaccinations']))
# Out:
# Test Statistic   -0.102637
# p-value           0.949175
# dtype: float64

# %%
# Run ADF test on differenced data.
interpret_dftest(adfuller(df['daily_vaccinations'].diff().dropna()))
# Out:
# Test Statistic   -1.043555e+01
# p-value           1.569898e-18
# dtype: float64

# %%
# Run ADF test on differenced data.
interpret_dftest(adfuller(df['daily_vaccinations_per_million']))
# Out:
# Test Statistic   -0.102982
# p-value           0.949141
# dtype: float64

# %%
# visualizing daily vaccinations trend
plt.figure(figsize=(12,8))
plt.title("Daily Vaccinations Trend")
plt.xlabel('Date')
plt.ylabel('Vaccinations')
plt.plot(df['daily_vaccinations']);

# %%
# daily vaccinations differenced once
plt.figure(figsize=(12,8))
plt.title("Daily Vaccinations Differenced Once")
plt.xlabel('Date')
plt.ylabel('Daily Vaccinations Diff 1')
plt.plot(df['daily_vaccinations'].diff().dropna());

# %%
# visualizing correlation of the features
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(), annot=True);

# %% [markdown]
# ## RNN Models

# %% [markdown]
# #### Only models with best MSE scores with least overfitting from each respective architecture are displayed below

# %% [markdown]
# ###  LSTM

# %%
# renaming the target variable to target
df.rename(columns={'daily_vaccinations': 'target'}, inplace=True)

# %%
dataset = df

# %%
# setting up variables in order to compare predictions later
df_train = df.iloc[0:55]
df_test = df.iloc[55:]

# %%
#scale the values - h/t machinelearningmastery.com
dataset = dataset.values
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

#divide the data into train and test data
train_size = int(len(dataset) * 0.85)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

#index the data into dependent and independent variables
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)

#convert data into suitable dimension for using it as input in LSTM network
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (73, 11) (73,) (14, 11) (14,)
# (73, 1, 11) (73,) (14, 1, 11) (14,)

# %%
# creating RNN
model = Sequential()
model.add(LSTM(256, activation = 'relu', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(256, activation = 'relu', input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(1, activation='relu'))
model.compile(loss='mse', optimizer=Adam(lr=0.0005), metrics=['acc', 'mae'])

# %%
# fitting model
history = model.fit(train_X, train_y, epochs=50, batch_size=64, validation_data=(test_X, test_y), verbose=0, shuffle=False)

# %%
# plotting model architecture
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
plt.figure(figsize=(8,6))
plt.title("Plots of RNNs Train and Test Loss'")
plt.plot(history.history['loss'], label='LSTM Train')
plt.plot(history.history['val_loss'], label='LSTM Test')
plt.xlabel("epochs")
plt.ylabel("loss (MSE)")
plt.legend()
plt.show()

# %%
plt.plot(history.history['acc'], label='train')
plt.plot(history.history['val_acc'], label='test')
plt.legend()
plt.show()

# %%
#prediction on training and testing data
train_predict = model.predict(train_X)    
test_predict = model.predict(test_X)

# %%
#converting from three dimension to two dimension
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# %%
inv_train_predict = np.concatenate((train_predict, train_X), axis=1)
inv_test_predict = np.concatenate((test_predict, test_X), axis=1)

# %%
#transforming to original scale
inv_train_predict = scaler.inverse_transform(inv_train_predict)
inv_test_predict = scaler.inverse_transform(inv_test_predict)

# %%
#predicted values on training data
inv_train_predict = inv_train_predict[:,0]
inv_train_predict

#predicted values on testing data
inv_test_predict = inv_test_predict[:,0]
inv_test_predict

#scaling back the original train labels
train_y = train_y.reshape((len(train_y), 1))
inv_train_y = np.concatenate((train_y, train_X), axis=1)
inv_train_y = scaler.inverse_transform(inv_train_y)
inv_train_y = inv_train_y[:,0]

#scaling back the original test labels
test_y = test_y.reshape((len(test_y), 1))
inv_test_y = np.concatenate((test_y, test_X), axis=1)
inv_test_y = scaler.inverse_transform(inv_test_y)
inv_test_y = inv_test_y[:,0]

# %%
#calculating rmse on train data
mse_train = mean_squared_error(inv_train_y, inv_train_predict)
print('Test MSE: %.3f' % mse_train)
# Out:
# Test MSE: 27325565.070

# %%
#calculating mse on test data
mse_test = mean_squared_error(inv_test_y, inv_test_predict)
print('Test MSE: %.3f' % mse_test)
# Out:
# Test MSE: 1947489.359

# %%
#plotting the graph of test actual vs predicted
inv_test_y = inv_test_y.reshape(-1,1)
inv_test_y.shape

t = np.arange(0,14,1)

plt.figure(figsize=(12,10))
plt.title('Actual Daily Vaccinations vs Predicted Daily Vaccinations')
plt.plot(t,inv_test_y,label="Actual")
plt.plot(t,inv_test_predict,'r',label="Predicted")
plt.xlabel('Timesteps')
plt.ylabel('Number of Vaccinations')
plt.legend()
plt.show()

# %% [markdown]
# ### GRU

# %%
dataset = df

# %%
df_train = df.iloc[0:55]
df_test = df.iloc[55:]

# %%
#scale the values
dataset = dataset.values
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

#divide the data into train and test data
train_size = int(len(dataset) * 0.85)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

#index the data into dependent and independent variables
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)

#convert data into suitable dimension for using it as input in LSTM network
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (73, 11) (73,) (14, 11) (14,)
# (73, 1, 11) (73,) (14, 1, 11) (14,)

# %%
model = Sequential()
model.add(GRU(256, activation='relu', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=True))
model.add(Dropout(0.2))
model.add(GRU(256, activation='relu', input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(1, activation = 'relu'))
model.compile(loss='mse', optimizer=Adam(lr=0.0005), metrics=['acc', 'mae'])

# %%
history = model.fit(train_X, train_y, epochs=50, batch_size=32, validation_data=(test_X, test_y), verbose=0, shuffle=False)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
plt.figure(figsize=(8,6))
plt.plot(history.history['loss'], label='GRU Train')
plt.plot(history.history['val_loss'], label='GRU Test')
plt.xlabel("epochs")
plt.ylabel("loss (MSE)")
plt.legend()
plt.show()

# %%
plt.plot(history.history['acc'], label='train')
plt.plot(history.history['val_acc'], label='test')
plt.legend()
plt.show()

# %%
#prediction on training and testing data
train_predict = model.predict(train_X)    
test_predict = model.predict(test_X)

# %%
#converting from three dimension to two dimension
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# %%
inv_train_predict = np.concatenate((train_predict, train_X), axis=1)
inv_test_predict = np.concatenate((test_predict, test_X), axis=1)

# %%
#transforming to original scale
inv_train_predict = scaler.inverse_transform(inv_train_predict)
inv_test_predict = scaler.inverse_transform(inv_test_predict)

# %%
#predicted values on training data
inv_train_predict = inv_train_predict[:,0]
inv_train_predict

#predicted values on testing data
inv_test_predict = inv_test_predict[:,0]
inv_test_predict

#scaling back the original train labels
train_y = train_y.reshape((len(train_y), 1))
inv_train_y = np.concatenate((train_y, train_X), axis=1)
inv_train_y = scaler.inverse_transform(inv_train_y)
inv_train_y = inv_train_y[:,0]

#scaling back the original test labels
test_y = test_y.reshape((len(test_y), 1))
inv_test_y = np.concatenate((test_y, test_X), axis=1)
inv_test_y = scaler.inverse_transform(inv_test_y)
inv_test_y = inv_test_y[:,0]

# %%
#calculating rmse on train data
mse_train = mean_squared_error(inv_train_y, inv_train_predict)
print('Test MSE: %.3f' % mse_train)
# Out:
# Test MSE: 1385402.743

# %%
#calculating mse on test data
mse_test = mean_squared_error(inv_test_y, inv_test_predict)
print('Test MSE: %.3f' % mse_test)
# Out:
# Test MSE: 449023.880

# %%
#plotting the graph of test actual vs predicted
inv_test_y = inv_test_y.reshape(-1,1)
inv_test_y.shape

t = np.arange(0,14,1)

plt.figure(figsize=(12,10))
plt.title('Actual Daily Vaccinations vs Predicted Daily Vaccinations')
plt.plot(t,inv_test_y,label="Actual")
plt.plot(t,inv_test_predict,'r',label="Predicted")
plt.xlabel('Timesteps')
plt.ylabel('Number of Vaccinations')
plt.legend()
plt.show()

# %% [markdown]
# ### Simple RNN

# %%
dataset = df

# %%
df_train = df.iloc[0:55]
df_test = df.iloc[55:]

# %%
#scale the values
dataset = dataset.values
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

#divide the data into train and test data
train_size = int(len(dataset) * 0.85)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

#index the data into dependent and independent variables
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)

#convert data into suitable dimension for using it as input in LSTM network
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (73, 11) (73,) (14, 11) (14,)
# (73, 1, 11) (73,) (14, 1, 11) (14,)

# %%
model = Sequential()
model.add(SimpleRNN(256, activation = 'relu', input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1, activation = 'relu'))
model.compile(loss='mse', optimizer=Adam(lr=0.0005), metrics=['acc', 'mae'])

# %%
history = model.fit(train_X, train_y, epochs=50, batch_size=32, validation_data=(test_X, test_y), verbose=0, shuffle=False)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
plt.figure(figsize=(8,6))
plt.plot(history.history['loss'], label='SimpleRNN Train')
plt.plot(history.history['val_loss'], label='SimpleRNN Test')
plt.xlabel("epochs")
plt.ylabel("loss (MSE)")
plt.legend()
plt.show()

# %%
plt.plot(history.history['acc'], label='train')
plt.plot(history.history['val_acc'], label='test')
plt.legend()
plt.show()

# %%
#prediction on training and testing data
train_predict = model.predict(train_X)    
test_predict = model.predict(test_X)

# %%
#converting from three dimension to two dimension
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# %%
inv_train_predict = np.concatenate((train_predict, train_X), axis=1)
inv_test_predict = np.concatenate((test_predict, test_X), axis=1)

# %%
#transforming to original scale
inv_train_predict = scaler.inverse_transform(inv_train_predict)
inv_test_predict = scaler.inverse_transform(inv_test_predict)

# %%
#predicted values on training data
inv_train_predict = inv_train_predict[:,0]
inv_train_predict

#predicted values on testing data
inv_test_predict = inv_test_predict[:,0]
inv_test_predict

#scaling back the original train labels
train_y = train_y.reshape((len(train_y), 1))
inv_train_y = np.concatenate((train_y, train_X), axis=1)
inv_train_y = scaler.inverse_transform(inv_train_y)
inv_train_y = inv_train_y[:,0]

#scaling back the original test labels
test_y = test_y.reshape((len(test_y), 1))
inv_test_y = np.concatenate((test_y, test_X), axis=1)
inv_test_y = scaler.inverse_transform(inv_test_y)
inv_test_y = inv_test_y[:,0]

# %%
#calculating rmse on train data
mse_train = mean_squared_error(inv_train_y, inv_train_predict)
print('Test MSE: %.3f' % mse_train)
# Out:
# Test MSE: 691060.515

# %%
#calculating mse on test data
mse_test = mean_squared_error(inv_test_y, inv_test_predict)
print('Test MSE: %.3f' % mse_test)
# Out:
# Test MSE: 227063.441

# %%
#plotting the graph of test actual vs predicted
inv_test_y = inv_test_y.reshape(-1,1)
inv_test_y.shape

t = np.arange(0,14,1)

plt.figure(figsize=(12,10))
plt.title('Actual Daily Vaccinations vs Predicted Daily Vaccinations')
plt.plot(t,inv_test_y,label="Actual")
plt.plot(t,inv_test_predict,'r',label="Predicted")
plt.xlabel('Timesteps')
plt.ylabel('Number of Vaccinations')
plt.legend()
plt.show()

# %% [markdown]
# ### Modeling on differenced data

# %%
# renaming target variable to target
df.rename(columns={'daily_vaccinations': 'target'}, inplace=True)

# %%
dataset = df.diff().dropna()

# %%
df_train = dataset.iloc[0:55]
df_test = dataset.iloc[55:]

# %%
#scale the values
dataset = dataset.values
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

#divide the data into train and test data
train_size = int(len(dataset) * 0.85)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

#index the data into dependent and independent variables
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)

#convert data into suitable dimension for using it as input in LSTM network
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (73, 11) (73,) (13, 11) (13,)
# (73, 1, 11) (73,) (13, 1, 11) (13,)

# %%
model = Sequential()
model.add(LSTM(256, activation = 'relu', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(256, activation = 'relu', input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(1, activation='relu'))
model.compile(loss='mse', optimizer=Adam(lr=0.0005), metrics=['acc', 'mae'])

# %%
history = model.fit(train_X, train_y, epochs=50, batch_size=64, validation_data=(test_X, test_y), verbose=0, shuffle=False)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
plt.plot(history.history['acc'], label='train')
plt.plot(history.history['val_acc'], label='test')
plt.legend()
plt.show()

# %%
#prediction on training and testing data
train_predict = model.predict(train_X)    
test_predict = model.predict(test_X)

# %%
#converting from three dimension to two dimension
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# %%
inv_train_predict = np.concatenate((train_predict, train_X), axis=1)
inv_test_predict = np.concatenate((test_predict, test_X), axis=1)

# %%
#transforming to original scale
inv_train_predict = scaler.inverse_transform(inv_train_predict)
inv_test_predict = scaler.inverse_transform(inv_test_predict)

# %%
#predicted values on training data
inv_train_predict = inv_train_predict[:,0]
inv_train_predict

#predicted values on testing data
inv_test_predict = inv_test_predict[:,0]
inv_test_predict

#scaling back the original train labels
train_y = train_y.reshape((len(train_y), 1))
inv_train_y = np.concatenate((train_y, train_X), axis=1)
inv_train_y = scaler.inverse_transform(inv_train_y)
inv_train_y = inv_train_y[:,0]

#scaling back the original test labels
test_y = test_y.reshape((len(test_y), 1))
inv_test_y = np.concatenate((test_y, test_X), axis=1)
inv_test_y = scaler.inverse_transform(inv_test_y)
inv_test_y = inv_test_y[:,0]

# %%
#calculating rmse on train data
mse_train = mean_squared_error(inv_train_y, inv_train_predict)
print('Test MSE: %.3f' % mse_train)
# Out:
# Test MSE: 2239266.650

# %%
#calculating mse on test data
mse_test = mean_squared_error(inv_test_y, inv_test_predict)
print('Test MSE: %.3f' % mse_test)
# Out:
# Test MSE: 1983951.715

# %%
#plotting the graph of test actual vs predicted
inv_test_y = inv_test_y.reshape(-1,1)
inv_test_y.shape

t = np.arange(0,13,1)

plt.figure(figsize=(12,10))
plt.title('Actual Daily Vaccinations vs Predicted Daily Vaccinations')
plt.plot(t,inv_test_y,label="Actual")
plt.plot(t,inv_test_predict,'r',label="Predicted")
plt.xlabel('Timesteps')
plt.ylabel('Number of Vaccinations')
plt.legend()
plt.show()

# %% [markdown]
# MSE of differenced data is significantly worse than on undifferenced data. Will not continue to perform modeling on differenced data for now.
